# %%
import pandas as pd

# %%
cat = pd.read_csv('PermutationImportance_Catboost_preprocessed.csv')
gb = pd.read_csv('PermutationImportance_GradientBoosting_preprocessed.csv')
rf = pd.read_csv('PermutationImportance_RandomForests_preprocessed.csv')
xgb = pd.read_csv('PermutationImportance_XGBoost_preprocessed.csv')

# %%
rf
# Out:
#     Unnamed: 0               feature      weight           std
# 0            0     Osmolarity (vein)  100.000000  1.993061e-02
# 1            1           Na + (vein)   82.650010  2.100163e-02
# 2            2           ctO2 (vein)    1.751713  7.284375e-04
# 3            3            Lac (vein)    1.171479  2.675037e-03
# 4            4            Cl- (vein)    0.128563  1.411341e-04
# 5            5           ctHb (vein)    0.098240  1.131119e-04
# 6            6            K + (vein)    0.094982  2.344077e-04
# 7            7         Ca2 + ( vein)    0.090243  2.665921e-04
# 8            8                   Age    0.088717  6.766986e-05
# 9            9            ABE (vein)    0.075718  2.392866e-04
# 10          10            p50 (vein)    0.063931  1.213547e-04
# 11          11           pCO2 (vein)    0.059375  2.794147e-05
# 12          12      HCO3- (P) (vein)    0.058601  9.500436e-05
# 13          13            pO2 (vein)    0.057786  7.702226e-05
# ...
