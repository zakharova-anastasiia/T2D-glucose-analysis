# %% [markdown]
# # Results

# %% [markdown]
# Neural Network: step - loss: 10.1535 - mse: 10.1535 - mae: 2.3596, r^2 0.38157956817989547!

# %% [markdown]
# ![photo_2020-09-10_18-40-44.jpg](attachment:photo_2020-09-10_18-40-44.jpg)

# %% [markdown]
# XGBOOST REGRESSOR
# mse: 0.9526391150577053
# mae: 0.684903509993609
# r^2: 0.9374612988739149
# ![Screenshot_4.jpg](attachment:Screenshot_4.jpg)

# %% [markdown]
# CATBOOST REGRESSOR
# mse: 0.8374064716346705
# mae: 0.624301923601688
# r^2: 0.9450260731237791
# ![Screenshot_5.jpg](attachment:Screenshot_5.jpg)
